# %% [markdown]
# ### using beautiful soup and collecting data : headers( article name, paragraphs,sub headers)

# %%
from  urllib.request import urlopen
from bs4 import BeautifulSoup
import re

def crawler():

    pages=set()
    count=0
    def getLinks(pageUrl,depth):
        nonlocal pages,count
        # to prohibit the recursion from going deep and continue infinitely
        if depth>=3:
            return 
        # open html
        try:
            
            html=urlopen("http://en.wikipedia.org{}".format(pageUrl))
            # create a beautiful soup object 
            bs=BeautifulSoup(html.read(),"html.parser")
            # find all the starts with wiki domain in their address
            try:
                print("header=",bs.h1.get_text())
                print("first paragraph= ", bs.find(id="mw-content-text").find_all('p')[0])
                print("Edit Links",bs.find(id='ca-edit').find('span').find('a').attrs["href"])
                
            except AttributeError as e:
                print(f"attribute error: {e}")
            except Exception as e:
                print(f"Exception occured: {e}")
                
            found_links=bs.find_all("a",href=re.compile('^(/wiki/)'))
            for link in found_links:
                # check if it is a link href in attrs of link or whatever we are iterating through
                # check if it is not visited yet
                if 'href' in link.attrs and link.attrs['href'] not in pages:
                    newPage=link.attrs['href']
                    count+=1
                    print(newPage,"depth",depth,"count=",count)
                    print('-'*20)
                    pages.add(newPage)
                    
                    # print(pages)
                    # add to visited 
                    # go and crawl this link 
                    getLinks(newPage,depth+1)
        except Exception as e:
            print(f"Excpetion occured: {e}")
            return 

    getLinks('',0)

# %%
crawler()
# Out:
# header= Main Page
# first paragraph=  <p>The <b><a href="/wiki/Siege_of_Constantinople_(674%E2%80%93678)" title="Siege of Constantinople (674–678)">first Arab siege of Constantinople in 674–678</a></b> was a major conflict of the <a href="/wiki/Arab%E2%80%93Byzantine_wars" title="Arab–Byzantine wars">Arab–Byzantine wars</a>, and the first culmination of the <a href="/wiki/Umayyad_Caliphate" title="Umayyad Caliphate">Umayyad Caliphate</a>'s expansionist strategy towards the <a href="/wiki/Byzantine_Empire_under_the_Heraclian_dynasty" title="Byzantine Empire under the Heraclian dynasty">Byzantine Empire</a>. In 672–673 Arab fleets secured bases along the coasts of <a href="/wiki/Anatolia" title="Anatolia">Asia Minor</a>, and set up a loose blockade around <a href="/wiki/Constantinople" title="Constantinople">Constantinople</a>. They used the peninsula of <a href="/wiki/Cyzicus" title="Cyzicus">Cyzicus</a> near the city as a base to spend the winter, and returned every spring to launch attacks against the <a href="/wiki/Walls_of_Constantinople" title="Walls of Constantinople">city's fortifications</a>. Finally the Byzantines managed to destroy the Arab navy using a new invention, the liquid incendiary substance known as <a href="/wiki/Greek_fire" title="Greek fire">Greek fire</a> <i>(pictured)</i>. The Byzantines also defeated the Arab land army in Asia Minor, forcing them to lift the siege. A peace treaty was signed, and following the outbreak of <a href="/wiki/Second_Fitna" title="Second Fitna">another Muslim civil war</a>, the Byzantines experienced a brief period of ascendancy. The siege was the first major Arab defeat in 50 years of expansion. Tales of a large-scale siege of Constantinople even reached China. (<b><a href="/wiki/Siege_of_Constantinople_(674%E2%80%93678)" title="Siege of Constantinople (674–678)">Full article...</a></b>)
# </p>
# attribute error: 'NoneType' object has no attribute 'find'
# /wiki/Main_Page depth 0 count= 1
# --------------------
# header= Main Page
# first paragraph=  <p>The <b><a href="/wiki/Siege_of_Constantinople_(674%E2%80%93678)" title="Siege of Constantinople (674–678)">first Arab siege of Constantinople in 674–678</a></b> was a major conflict of the <a href="/wiki/Arab%E2%80%93Byzantine_wars" title="Arab–Byzantine wars">Arab–Byzantine wars</a>, and the first culmination of the <a href="/wiki/Umayyad_Caliphate" title="Umayyad Caliphate">Umayyad Caliphate</a>'s expansionist strategy towards the <a href="/wiki/Byzantine_Empire_under_the_Heraclian_dynasty" title="Byzantine Empire under the Heraclian dynasty">Byzantine Empire</a>. In 672–673 Arab fleets secured bases along the coasts of <a href="/wiki/Anatolia" title="Anatolia">Asia Minor</a>, and set up a loose blockade around <a href="/wiki/Constantinople" title="Constantinople">Constantinople</a>. They used the peninsula of <a href="/wiki/Cyzicus" title="Cyzicus">Cyzicus</a> near the city as a base to spend the winter, and returned every spring to launch attacks against the <a href="/wiki/Walls_of_Constantinople" title="Walls of Constantinople">city's fortifications</a>. Finally the Byzantines managed to destroy the Arab navy using a new invention, the liquid incendiary substance known as <a href="/wiki/Greek_fire" title="Greek fire">Greek fire</a> <i>(pictured)</i>. The Byzantines also defeated the Arab land army in Asia Minor, forcing them to lift the siege. A peace treaty was signed, and following the outbreak of <a href="/wiki/Second_Fitna" title="Second Fitna">another Muslim civil war</a>, the Byzantines experienced a brief period of ascendancy. The siege was the first major Arab defeat in 50 years of expansion. Tales of a large-scale siege of Constantinople even reached China. (<b><a href="/wiki/Siege_of_Constantinople_(674%E2%80%93678)" title="Siege of Constantinople (674–678)">Full article...</a></b>)
# </p>
# attribute error: 'NoneType' object has no attribute 'find'
# /wiki/Wikipedia:Contents depth 1 count= 2
# --------------------
# header= Wikipedia:Contents
# first paragraph=  <p class="mw-empty-elt">
# </p>
# attribute error: 'NoneType' object has no attribute 'find'
# /wiki/Portal:Current_events depth 2 count= 3
# --------------------
# /wiki/Special:Random depth 2 count= 4
# --------------------
# /wiki/Wikipedia:About depth 2 count= 5
# --------------------
# /wiki/Help:Contents depth 2 count= 6
# --------------------
# /wiki/Help:Introduction depth 2 count= 7
# --------------------
# /wiki/Wikipedia:Community_portal depth 2 count= 8
# --------------------
# /wiki/Special:RecentChanges depth 2 count= 9
# --------------------
# /wiki/Wikipedia:File_upload_wizard depth 2 count= 10
# --------------------
# /wiki/Special:Search depth 2 count= 11
# --------------------
# /wiki/Special:MyContributions depth 2 count= 12
# --------------------
# /wiki/Special:MyTalk depth 2 count= 13
# --------------------
# /wiki/Wikipedia_talk:Contents depth 2 count= 14
# --------------------
# /wiki/Special:WhatLinksHere/Wikipedia:Contents depth 2 count= 15
# --------------------
# /wiki/Special:RecentChangesLinked/Wikipedia:Contents depth 2 count= 16
# --------------------
# /wiki/Wikipedia:File_Upload_Wizard depth 2 count= 17
# --------------------
# /wiki/Special:SpecialPages depth 2 count= 18
# --------------------
# /wiki/Wikipedia:Protection_policy#semi depth 2 count= 19
# --------------------
# /wiki/Wikipedia:Contents/Overviews depth 2 count= 20
# --------------------
# /wiki/Wikipedia:Contents/Outlines depth 2 count= 21
# --------------------
# /wiki/Wikipedia:Contents/Lists depth 2 count= 22
# --------------------
# /wiki/Wikipedia:Contents/Portals depth 2 count= 23
# --------------------
# /wiki/Wikipedia:Contents/Glossaries depth 2 count= 24
# --------------------
# /wiki/Wikipedia:Contents/Categories depth 2 count= 25
# --------------------
# /wiki/Wikipedia:Vital_articles depth 2 count= 26
# --------------------
# /wiki/Wikipedia:Featured_content depth 2 count= 27
# --------------------
# /wiki/Wikipedia:Good_articles depth 2 count= 28
# --------------------
# /wiki/Wikipedia:Contents/Indices depth 2 count= 29
# --------------------
# /wiki/Wikipedia:Contents/A%E2%80%93Z_index depth 2 count= 30
# --------------------
# /wiki/Wikipedia:Contents/Reference depth 2 count= 31
# --------------------
# /wiki/Wikipedia:Contents/Culture_and_the_arts depth 2 count= 32
# --------------------
# /wiki/Wikipedia:Contents/Geography_and_places depth 2 count= 33
# --------------------
# /wiki/Wikipedia:Contents/Health_and_fitness depth 2 count= 34
# --------------------
# /wiki/Wikipedia:Contents/History_and_events depth 2 count= 35
# --------------------
# /wiki/Wikipedia:Contents/Human_activities depth 2 count= 36
# --------------------
# /wiki/Wikipedia:Contents/Mathematics_and_logic depth 2 count= 37
# --------------------
# /wiki/Wikipedia:Contents/Natural_and_physical_sciences depth 2 count= 38
# --------------------
# /wiki/Wikipedia:Contents/People_and_self depth 2 count= 39
# --------------------
# /wiki/Wikipedia:Contents/Philosophy_and_thinking depth 2 count= 40
# --------------------
# /wiki/Wikipedia:Contents/Religion_and_belief_systems depth 2 count= 41
# --------------------
# /wiki/Wikipedia:Contents/Society_and_social_sciences depth 2 count= 42
# --------------------
# /wiki/Wikipedia:Contents/Technology_and_applied_sciences depth 2 count= 43
# --------------------
# /wiki/Wikipedia:Directories_and_indexes depth 2 count= 44
# --------------------
# /wiki/Wikipedia:Shortcut depth 2 count= 45
# --------------------
# /wiki/Wikipedia depth 2 count= 46
# --------------------
# /wiki/List_of_timelines depth 2 count= 47
# --------------------
# /wiki/2024 depth 2 count= 48
# --------------------
# /wiki/2024_in_science depth 2 count= 49
# --------------------
# /wiki/Library_of_Congress_Classification depth 2 count= 50
# --------------------
# /wiki/List_of_Dewey_Decimal_classes depth 2 count= 51
# --------------------
# /wiki/Figurative_system_of_human_knowledge depth 2 count= 52
# --------------------
# /wiki/Encyclop%C3%A9die depth 2 count= 53
# --------------------
# /wiki/Prop%C3%A6dia depth 2 count= 54
# --------------------
# /wiki/Encyclop%C3%A6dia_Britannica depth 2 count= 55
# --------------------
# /wiki/Tree_of_knowledge_system depth 2 count= 56
# --------------------
# /wiki/Universal_Decimal_Classification#UDC_outline depth 2 count= 57
# --------------------
# /wiki/Wikipedia:List_of_bibliographies depth 2 count= 58
# --------------------
# /wiki/Category:Wikipedia_bibliographies depth 2 count= 59
# --------------------
# /wiki/Category:Main_topic_classifications depth 2 count= 60
# --------------------
# /wiki/Category:People depth 2 count= 61
# --------------------
# /wiki/Wikipedia:Vital_articles/Level/1 depth 2 count= 62
# --------------------
# /wiki/Wikipedia:Vital_articles/Level/2 depth 2 count= 63
# --------------------
# /wiki/Wikipedia:Vital_articles/Level/3 depth 2 count= 64
# --------------------
# /wiki/Wikipedia:Vital_articles/Level/4 depth 2 count= 65
# --------------------
# /wiki/Wikipedia:Vital_articles/Level/5 depth 2 count= 66
# --------------------
# /wiki/Wikipedia:List_of_articles_every_Wikipedia_should_have depth 2 count= 67
# --------------------
# /wiki/Wikipedia:List_of_articles_every_Wikipedia_should_have/Expanded depth 2 count= 68
# --------------------
# /wiki/Wikipedia:Featured_articles depth 2 count= 69
# --------------------
# /wiki/Wikipedia:Featured_lists depth 2 count= 70
# --------------------
# /wiki/Wikipedia:Featured_pictures depth 2 count= 71
# --------------------
# /wiki/Wikipedia:Featured_topics depth 2 count= 72
# --------------------
# /wiki/Wikipedia:Good_topics depth 2 count= 73
# --------------------
# /wiki/Category:Spoken_articles depth 2 count= 74
# --------------------
# /wiki/Wikipedia:Spoken_articles depth 2 count= 75
# --------------------
# /wiki/Special:AllPages depth 2 count= 76
# --------------------
# /wiki/Category:Wikipedia_indexes depth 2 count= 77
# --------------------
# /wiki/Outline_of_academic_disciplines depth 2 count= 78
# --------------------
# /wiki/List_of_days_of_the_year depth 2 count= 79
# --------------------
# /wiki/November_9 depth 2 count= 80
# --------------------
# /wiki/Lists_of_sovereign_states_and_dependent_territories depth 2 count= 81
# --------------------
# /wiki/List_of_decades,_centuries,_and_millennia depth 2 count= 82
# --------------------
# /wiki/Template:Wikipedia_directories depth 2 count= 83
# --------------------
# /wiki/Template_talk:Wikipedia_directories depth 2 count= 84
# --------------------
# /wiki/Special:EditPage/Template:Wikipedia_directories depth 2 count= 85
# --------------------
# /wiki/Wikipedia:ADMINP depth 2 count= 86
# --------------------
# /wiki/Wikipedia:List_of_policies_and_guidelines depth 2 count= 87
# --------------------
# /wiki/Wikipedia:List_of_policies depth 2 count= 88
# --------------------
# /wiki/Wikipedia:List_of_guidelines depth 2 count= 89
# --------------------
# /wiki/Wikipedia:Manual_of_Style/Contents depth 2 count= 90
# --------------------
# /wiki/Help:Directory depth 2 count= 91
# --------------------
# /wiki/Help:Menu depth 2 count= 92
# --------------------
# /wiki/Wikipedia:FAQ depth 2 count= 93
# --------------------
# /wiki/Wikipedia:Request_directory depth 2 count= 94
# --------------------
# /wiki/Wikipedia:Reader%27s_index_to_Wikipedia depth 2 count= 95
# --------------------
# /wiki/Wikipedia:Tips depth 2 count= 96
# --------------------
# /wiki/Wikipedia:Styletips depth 2 count= 97
# --------------------
# /wiki/Wikipedia:Tools depth 2 count= 98
# --------------------
# /wiki/Wikipedia:Dashboard depth 2 count= 99
# --------------------
# /wiki/Wikipedia:Noticeboards#List_of_Wikipedia's_noticeboards depth 2 count= 100
# --------------------
# /wiki/Wikipedia:Essay_directory depth 2 count= 101
# --------------------
# /wiki/Wikipedia:Editor%27s_index_to_Wikipedia depth 2 count= 102
# --------------------
# /wiki/Wikipedia:Department_directory depth 2 count= 103
# --------------------
# /wiki/Wikipedia:Maintenance depth 2 count= 104
# --------------------
# /wiki/Wikipedia:Open_letters depth 2 count= 105
# --------------------
# /wiki/Wikipedia:WikiProject_Council/Directory depth 2 count= 106
# --------------------
# /wiki/Help:Wikitext depth 2 count= 107
# --------------------
# /wiki/Help:HTML_in_wikitext depth 2 count= 108
# --------------------
# /wiki/Wikipedia:Template_index depth 2 count= 109
# --------------------
# /wiki/Wikipedia:Wikipedia_abbreviations depth 2 count= 110
# --------------------
# /wiki/Wikipedia:Edit_summary_legend depth 2 count= 111
# --------------------
# /wiki/Wikipedia:Glossary depth 2 count= 112
# --------------------
# /wiki/Wikipedia:Shortcut_index depth 2 count= 113
# --------------------
# /wiki/Deaths_in_2024 depth 2 count= 114
# --------------------
# /wiki/Help:Searching#Custom_search_boxes depth 2 count= 115
# --------------------
# /wiki/Help:Category depth 2 count= 116
# --------------------
# /wiki/Category:Wikipedia_directories depth 2 count= 117
# --------------------
# /wiki/Category:Wikipedia_contents depth 2 count= 118
# --------------------
# /wiki/Category:Wikipedia_navigation depth 2 count= 119
# --------------------
# /wiki/Category:Wikipedia_semi-protected_project_pages depth 2 count= 120
# --------------------
# /wiki/Category:Wikipedia_move-protected_project_pages depth 2 count= 121
# --------------------
# /wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License depth 2 count= 122
# --------------------
# /wiki/Wikipedia:General_disclaimer depth 2 count= 123
# --------------------
# /wiki/Talk:Main_Page depth 1 count= 124
# --------------------
# header= Talk:Main Page
# first paragraph=  <p style="text-align: center;"><b>If you have a question related to the Main Page, please search the talk page archives first to check if it has previously been addressed:</b></p>
# attribute error: 'NoneType' object has no attribute 'find'
# /wiki/Special:WhatLinksHere/Talk:Main_Page depth 2 count= 125
# --------------------
# /wiki/Special:RecentChangesLinked/Talk:Main_Page depth 2 count= 126
# --------------------
# /wiki/Wikipedia:Teahouse depth 2 count= 127
# --------------------
# /wiki/Wikipedia:Main_Page/Errors depth 2 count= 128
# --------------------
# /wiki/English_Wikipedia depth 2 count= 129
# --------------------
# /wiki/Wikipedia:What_is_an_article%3F depth 2 count= 130
# --------------------
# /wiki/Wikipedia:Redirect depth 2 count= 131
# --------------------
# /wiki/Wikipedia:Article_wizard depth 2 count= 132
# --------------------
# /wiki/Wikipedia:Help_desk depth 2 count= 133
# --------------------
# /wiki/Help:Editing depth 2 count= 134
# --------------------
# /wiki/Help:Files depth 2 count= 135
# --------------------
# /wiki/Wikipedia:Village_pump depth 2 count= 136
# --------------------
# /wiki/Wikipedia:Reference_desk depth 2 count= 137
# --------------------
# /wiki/Wikipedia:Administrators%27_noticeboard depth 2 count= 138
# --------------------
# /wiki/Wikipedia:Vandalism depth 2 count= 139
# --------------------
# /wiki/Wikipedia:Questions depth 2 count= 140
# --------------------
# /wiki/Wikipedia:Today%27s_featured_article/requests depth 2 count= 141
# --------------------
# /wiki/Wikipedia:Today%27s_featured_article depth 2 count= 142
# --------------------
# /wiki/Wikipedia:In_the_news/Candidates depth 2 count= 143
# --------------------
# /wiki/Wikipedia:In_the_news depth 2 count= 144
# --------------------
# /wiki/Template_talk:Did_you_know depth 2 count= 145
# --------------------
# /wiki/Wikipedia:Did_you_know depth 2 count= 146
# --------------------
# /wiki/Wikipedia:Selected_anniversaries depth 2 count= 147
# --------------------
# /wiki/Wikipedia:Today%27s_featured_list/Submissions depth 2 count= 148
# --------------------
# /wiki/Wikipedia:Today%27s_featured_list depth 2 count= 149
# --------------------
# /wiki/Wikipedia:Featured_picture_candidates depth 2 count= 150
# --------------------
# /wiki/Wikipedia:Picture_of_the_day depth 2 count= 151
# --------------------
# /wiki/FIFO_(computing_and_electronics) depth 2 count= 152
# --------------------
# /wiki/Template_talk:Wikipedia_languages depth 2 count= 153
# --------------------
# /wiki/Wikipedia:FAQ/Main_Page depth 2 count= 154
# --------------------
# /wiki/Template:Main_Page_topics depth 2 count= 155
# --------------------
# /wiki/Template_talk:Main_Page_topics depth 2 count= 156
# --------------------
# /wiki/Special:EditPage/Template:Main_Page_topics depth 2 count= 157
# --------------------
# /wiki/Wikipedia:Main_Page/Errors/Administrator_instructions depth 2 count= 158
# --------------------
# /wiki/Wikipedia:Main_Page_alternatives depth 2 count= 159
# --------------------
# /wiki/Wikipedia:Editing_the_main_page depth 2 count= 160
# --------------------
# /wiki/Wikipedia:Main_Page_design depth 2 count= 161
# --------------------
# /wiki/Wikipedia:Main_Page_queue depth 2 count= 162
# --------------------
# /wiki/Wikipedia:Main_Page/Yesterday depth 2 count= 163
# --------------------
# /wiki/Wikipedia:Main_Page/Tomorrow depth 2 count= 164
# --------------------
# /wiki/Wikipedia:Main_Page_history depth 2 count= 165
# --------------------
# /wiki/Template:Wikipedia_languages depth 2 count= 166
# --------------------
# /wiki/Template:Wikipedia%27s_sister_projects depth 2 count= 167
# --------------------
# /wiki/Wikipedia:Main_Page/sandbox depth 2 count= 168
# --------------------
# /wiki/Wikipedia:April_Fools%27_Main_Page depth 2 count= 169
# --------------------
# /wiki/Wikipedia:Don%27t_delete_the_main_page depth 2 count= 170
# --------------------
# /wiki/Wikipedia:Today%27s_featured_article/requests/pending depth 2 count= 171
# --------------------
# /wiki/Wikipedia:Today%27s_featured_article/recent_TFAs depth 2 count= 172
# --------------------
# /wiki/Wikipedia:Today%27s_featured_article_oddities depth 2 count= 173
# --------------------
# /wiki/Wikipedia:Today%27s_featured_article/Most_viewed depth 2 count= 174
# --------------------
# /wiki/Wikipedia:Featured_articles_that_haven%27t_been_on_the_Main_Page depth 2 count= 175
# --------------------
# /wiki/Wikipedia:Featured_article_criteria depth 2 count= 176
# --------------------
# /wiki/Wikipedia:Featured_article_candidates depth 2 count= 177
# --------------------
# /wiki/Wikipedia:Featured_article_candidates/Featured_log depth 2 count= 178
# --------------------
# /wiki/Wikipedia:Featured_article_review depth 2 count= 179
# --------------------
# /wiki/Wikipedia:Featured_article_review/archive depth 2 count= 180
# --------------------
# /wiki/Wikipedia:Featured_article_statistics depth 2 count= 181
# --------------------
# /wiki/Wikipedia:Former_featured_articles depth 2 count= 182
# --------------------
# /wiki/Wikipedia:Unreviewed_featured_articles depth 2 count= 183
# --------------------
# /wiki/Template:Did_you_know depth 2 count= 184
# --------------------
# /wiki/Wikipedia_talk:Did_you_know depth 2 count= 185
# --------------------
# /wiki/Wikipedia:Did_you_know#Rules depth 2 count= 186
# --------------------
# /wiki/Wikipedia:Did_you_know/Guidelines depth 2 count= 187
# --------------------
# /wiki/Wikipedia:Did_you_know/Reviewer_instructions depth 2 count= 188
# --------------------
# /wiki/Template:Did_you_know/Queue depth 2 count= 189
# --------------------
# /wiki/Wikipedia:Recent_additions depth 2 count= 190
# --------------------
# /wiki/Wikipedia:Did_you_know/Statistics depth 2 count= 191
# --------------------
# /wiki/Template:In_the_news depth 2 count= 192
# --------------------
# /wiki/Wikipedia:Main_Page/Errors#Errors_in_In_the_news depth 2 count= 193
# --------------------
# /wiki/Wikipedia_talk:In_the_news depth 2 count= 194
# --------------------
# /wiki/Wikipedia:In_the_news/Administrator_instructions depth 2 count= 195
# --------------------
# /wiki/Wikipedia:In_the_news#Recent_deaths_section depth 2 count= 196
# --------------------
# /wiki/Wikipedia:In_the_news/Recurring_items depth 2 count= 197
# --------------------
# /wiki/Wikipedia:In_the_news/Recurring_items#Awards depth 2 count= 198
# --------------------
# /wiki/Wikipedia:In_the_news/Recurring_items#Sports depth 2 count= 199
# --------------------
# /wiki/Wikipedia_talk:In_the_news/Recurring_items depth 2 count= 200
# --------------------
# /wiki/Wikipedia:In_the_news/Candidates/Archives depth 2 count= 201
# --------------------
# /wiki/Wikipedia:In_the_news/Posted/Archives depth 2 count= 202
# --------------------
# /wiki/Portal:Current_events/Sports depth 2 count= 203
# --------------------
# /wiki/Portal_talk:Current_events depth 2 count= 204
# --------------------
# /wiki/Wikipedia:How_the_Current_events_page_works depth 2 count= 205
# --------------------
# /wiki/Portal:Current_events/How_to_archive_the_portal depth 2 count= 206
# --------------------
# /wiki/Wikipedia_talk:Selected_anniversaries depth 2 count= 207
# --------------------
# /wiki/Wikipedia:Selected_anniversaries/Holidays_and_observances depth 2 count= 208
# --------------------
# /wiki/Wikipedia:Selected_anniversaries/All depth 2 count= 209
# --------------------
# /wiki/Wikipedia:Today%27s_featured_list/Statistics depth 2 count= 210
# --------------------
# /wiki/Wikipedia:Today%27s_featured_list/Previously_run_lists depth 2 count= 211
# --------------------
# /wiki/Wikipedia:Today%27s_featured_list/Get_involved depth 2 count= 212
# --------------------
# /wiki/Wikipedia:Featured_list_criteria depth 2 count= 213
# --------------------
# /wiki/Wikipedia:Featured_list_candidates depth 2 count= 214
# --------------------
# /wiki/Wikipedia:Featured_list_candidates/Featured_log depth 2 count= 215
# --------------------
# /wiki/Wikipedia:Featured_list_candidates/Task_force depth 2 count= 216
# --------------------
# /wiki/Wikipedia:Featured_list_removal_candidates depth 2 count= 217
# --------------------
# /wiki/Wikipedia:Featured_lists/Review_list depth 2 count= 218
# --------------------
# /wiki/Wikipedia:Featured_list_removal_candidates/log depth 2 count= 219
# --------------------
# /wiki/Wikipedia:Former_featured_lists depth 2 count= 220
# --------------------
# /wiki/Wikipedia:Picture_of_the_day/Guidelines depth 2 count= 221
# --------------------
# /wiki/Wikipedia:Picture_of_the_day/Unused depth 2 count= 222
# --------------------
# /wiki/Wikipedia:Picture_of_the_day/Archive depth 2 count= 223
# --------------------
# /wiki/Wikipedia:Picture_of_the_day/Tomorrow depth 2 count= 224
# --------------------
# /wiki/Wikipedia:Featured_picture_criteria depth 2 count= 225
# --------------------
# /wiki/Wikipedia:Featured_picture_candidates/Nomination_procedure depth 2 count= 226
# --------------------
# /wiki/Wikipedia:Featured_topics/Main_Page_appearances depth 2 count= 227
# --------------------
# /wiki/Wikipedia:Featured_topic_candidates depth 2 count= 228
# --------------------
# /wiki/Wikipedia:Featured_topic_candidates/Featured_log depth 2 count= 229
# --------------------
# /wiki/Wikipedia:Featured_topic_candidates/Nomination_procedure depth 2 count= 230
# --------------------
# /wiki/Wikipedia:Featured_topic_criteria depth 2 count= 231
# --------------------
# /wiki/Wikipedia:Featured_topic_removal_candidates depth 2 count= 232
# --------------------
# /wiki/Wikipedia:Former_featured_topics depth 2 count= 233
# --------------------
# /wiki/Wikipedia_talk:Featured_topic_questions depth 2 count= 234
# --------------------
# /wiki/File:Semi-protection-shackle.svg depth 2 count= 235
# --------------------
# /wiki/Wikipedia:User_access_levels#New_users depth 2 count= 236
# --------------------
# /wiki/Wikipedia:User_access_levels#Unregistered_users depth 2 count= 237
# --------------------
# /wiki/Help:Protection depth 2 count= 238
# --------------------
# /wiki/Wikipedia:Protection_policy depth 2 count= 239
# --------------------
# /wiki/Wikipedia:Requests_for_page_protection#Current_requests_for_reduction_in_protection_level depth 2 count= 240
# --------------------
# /wiki/Special:UserLogin depth 2 count= 241
# --------------------
# /wiki/Special:UserLogin/signup depth 2 count= 242
# --------------------
# /wiki/Talk:Main_Page/Archive_207 depth 2 count= 243
# --------------------
# /wiki/Talk:Main_Page/Archive_1 depth 2 count= 244
# --------------------
# /wiki/Talk:Main_Page/Archive_2 depth 2 count= 245
# --------------------
# /wiki/Talk:Main_Page/Archive_3 depth 2 count= 246
# --------------------
# /wiki/Talk:Main_Page/Archive_4 depth 2 count= 247
# --------------------
# /wiki/Talk:Main_Page/Archive_5 depth 2 count= 248
# --------------------
# /wiki/Talk:Main_Page/Archive_6 depth 2 count= 249
# --------------------
# /wiki/Talk:Main_Page/Archive_7 depth 2 count= 250
# --------------------
# /wiki/Talk:Main_Page/Archive_8 depth 2 count= 251
# --------------------
# /wiki/Talk:Main_Page/Archive_9 depth 2 count= 252
# --------------------
# /wiki/Talk:Main_Page/Archive_10 depth 2 count= 253
# --------------------
# /wiki/Talk:Main_Page/Archive_11 depth 2 count= 254
# --------------------
# /wiki/Talk:Main_Page/Archive_12 depth 2 count= 255
# --------------------
# /wiki/Talk:Main_Page/Archive_13 depth 2 count= 256
# --------------------
# /wiki/Talk:Main_Page/Archive_14 depth 2 count= 257
# --------------------
# /wiki/Talk:Main_Page/Archive_15 depth 2 count= 258
# --------------------
# /wiki/Talk:Main_Page/Archive_16 depth 2 count= 259
# --------------------
# /wiki/Talk:Main_Page/Archive_17 depth 2 count= 260
# --------------------
# /wiki/Talk:Main_Page/Archive_18 depth 2 count= 261
# --------------------
# /wiki/Talk:Main_Page/Archive_19 depth 2 count= 262
# --------------------
# /wiki/Talk:Main_Page/Archive_20 depth 2 count= 263
# --------------------
# /wiki/Talk:Main_Page/Archive_21 depth 2 count= 264
# --------------------
# /wiki/Talk:Main_Page/Archive_22 depth 2 count= 265
# --------------------
# /wiki/Talk:Main_Page/Archive_23 depth 2 count= 266
# --------------------
# /wiki/Talk:Main_Page/Archive_24 depth 2 count= 267
# --------------------
# /wiki/Talk:Main_Page/Archive_25 depth 2 count= 268
# --------------------
# /wiki/Talk:Main_Page/Archive_26 depth 2 count= 269
# --------------------
# /wiki/Talk:Main_Page/Archive_27 depth 2 count= 270
# --------------------
# /wiki/Talk:Main_Page/Archive_28 depth 2 count= 271
# --------------------
# /wiki/Talk:Main_Page/Archive_29 depth 2 count= 272
# --------------------
# /wiki/Talk:Main_Page/Archive_30 depth 2 count= 273
# --------------------
# /wiki/Talk:Main_Page/Archive_31 depth 2 count= 274
# --------------------
# /wiki/Talk:Main_Page/Archive_32 depth 2 count= 275
# --------------------
# /wiki/Talk:Main_Page/Archive_33 depth 2 count= 276
# --------------------
# /wiki/Talk:Main_Page/Archive_34 depth 2 count= 277
# --------------------
# /wiki/Talk:Main_Page/Archive_35 depth 2 count= 278
# --------------------
# /wiki/Talk:Main_Page/Archive_36 depth 2 count= 279
# --------------------
# /wiki/Talk:Main_Page/Archive_37 depth 2 count= 280
# --------------------
# /wiki/Talk:Main_Page/Archive_38 depth 2 count= 281
# --------------------
# /wiki/Talk:Main_Page/Archive_39 depth 2 count= 282
# --------------------
# /wiki/Talk:Main_Page/Archive_40 depth 2 count= 283
# --------------------
# /wiki/Talk:Main_Page/Archive_41 depth 2 count= 284
# --------------------
# /wiki/Talk:Main_Page/Archive_42 depth 2 count= 285
# --------------------
# /wiki/Talk:Main_Page/Archive_43 depth 2 count= 286
# --------------------
# /wiki/Talk:Main_Page/Archive_44 depth 2 count= 287
# --------------------
# /wiki/Talk:Main_Page/Archive_45 depth 2 count= 288
# --------------------
# /wiki/Talk:Main_Page/Archive_46 depth 2 count= 289
# --------------------
# /wiki/Talk:Main_Page/Archive_47 depth 2 count= 290
# --------------------
# /wiki/Talk:Main_Page/Archive_48 depth 2 count= 291
# --------------------
# /wiki/Talk:Main_Page/Archive_49 depth 2 count= 292
# --------------------
# /wiki/Talk:Main_Page/Archive_50 depth 2 count= 293
# --------------------
# /wiki/Talk:Main_Page/Archive_51 depth 2 count= 294
# --------------------
# /wiki/Talk:Main_Page/Archive_52 depth 2 count= 295
# --------------------
# /wiki/Talk:Main_Page/Archive_53 depth 2 count= 296
# --------------------
# /wiki/Talk:Main_Page/Archive_54 depth 2 count= 297
# --------------------
# /wiki/Talk:Main_Page/Archive_55 depth 2 count= 298
# --------------------
# /wiki/Talk:Main_Page/Archive_56 depth 2 count= 299
# --------------------
# /wiki/Talk:Main_Page/Archive_57 depth 2 count= 300
# --------------------
# /wiki/Talk:Main_Page/Archive_58 depth 2 count= 301
# --------------------
# /wiki/Talk:Main_Page/Archive_59 depth 2 count= 302
# --------------------
# /wiki/Talk:Main_Page/Archive_60 depth 2 count= 303
# --------------------
# /wiki/Talk:Main_Page/Archive_61 depth 2 count= 304
# --------------------
# /wiki/Talk:Main_Page/Archive_62 depth 2 count= 305
# --------------------
# /wiki/Talk:Main_Page/Archive_63 depth 2 count= 306
# --------------------
# /wiki/Talk:Main_Page/Archive_64 depth 2 count= 307
# --------------------
# /wiki/Talk:Main_Page/Archive_65 depth 2 count= 308
# --------------------
# /wiki/Talk:Main_Page/Archive_66 depth 2 count= 309
# --------------------
# /wiki/Talk:Main_Page/Archive_67 depth 2 count= 310
# --------------------
# /wiki/Talk:Main_Page/Archive_68 depth 2 count= 311
# --------------------
# /wiki/Talk:Main_Page/Archive_69 depth 2 count= 312
# --------------------
# /wiki/Talk:Main_Page/Archive_70 depth 2 count= 313
# --------------------
# /wiki/Talk:Main_Page/Archive_71 depth 2 count= 314
# --------------------
# /wiki/Talk:Main_Page/Archive_72 depth 2 count= 315
# --------------------
# /wiki/Talk:Main_Page/Archive_73 depth 2 count= 316
# --------------------
# /wiki/Talk:Main_Page/Archive_74 depth 2 count= 317
# --------------------
# /wiki/Talk:Main_Page/Archive_75 depth 2 count= 318
# --------------------
# /wiki/Talk:Main_Page/Archive_76 depth 2 count= 319
# --------------------
# /wiki/Talk:Main_Page/Archive_77 depth 2 count= 320
# --------------------
# /wiki/Talk:Main_Page/Archive_78 depth 2 count= 321
# --------------------
# /wiki/Talk:Main_Page/Archive_79 depth 2 count= 322
# --------------------
# /wiki/Talk:Main_Page/Archive_80 depth 2 count= 323
# --------------------
# /wiki/Talk:Main_Page/Archive_81 depth 2 count= 324
# --------------------
# /wiki/Talk:Main_Page/Archive_82 depth 2 count= 325
# --------------------
# /wiki/Talk:Main_Page/Archive_83 depth 2 count= 326
# --------------------
# /wiki/Talk:Main_Page/Archive_84 depth 2 count= 327
# --------------------
# /wiki/Talk:Main_Page/Archive_85 depth 2 count= 328
# --------------------
# /wiki/Talk:Main_Page/Archive_86 depth 2 count= 329
# --------------------
# /wiki/Talk:Main_Page/Archive_87 depth 2 count= 330
# --------------------
# /wiki/Talk:Main_Page/Archive_88 depth 2 count= 331
# --------------------
# /wiki/Talk:Main_Page/Archive_89 depth 2 count= 332
# --------------------
# /wiki/Talk:Main_Page/Archive_90 depth 2 count= 333
# --------------------
# /wiki/Talk:Main_Page/Archive_91 depth 2 count= 334
# --------------------
# /wiki/Talk:Main_Page/Archive_92 depth 2 count= 335
# --------------------
# /wiki/Talk:Main_Page/Archive_93 depth 2 count= 336
# --------------------
# /wiki/Talk:Main_Page/Archive_94 depth 2 count= 337
# --------------------
# /wiki/Talk:Main_Page/Archive_95 depth 2 count= 338
# --------------------
# /wiki/Talk:Main_Page/Archive_96 depth 2 count= 339
# --------------------
# /wiki/Talk:Main_Page/Archive_97 depth 2 count= 340
# --------------------
# /wiki/Talk:Main_Page/Archive_98 depth 2 count= 341
# --------------------
# /wiki/Talk:Main_Page/Archive_99 depth 2 count= 342
# --------------------
# /wiki/Talk:Main_Page/Archive_100 depth 2 count= 343
# --------------------
# /wiki/Talk:Main_Page/Archive_101 depth 2 count= 344
# --------------------
# /wiki/Talk:Main_Page/Archive_102 depth 2 count= 345
# --------------------
# /wiki/Talk:Main_Page/Archive_103 depth 2 count= 346
# --------------------
# /wiki/Talk:Main_Page/Archive_104 depth 2 count= 347
# --------------------
# /wiki/Talk:Main_Page/Archive_105 depth 2 count= 348
# --------------------
# /wiki/Talk:Main_Page/Archive_106 depth 2 count= 349
# --------------------
# /wiki/Talk:Main_Page/Archive_107 depth 2 count= 350
# --------------------
# /wiki/Talk:Main_Page/Archive_108 depth 2 count= 351
# --------------------
# /wiki/Talk:Main_Page/Archive_109 depth 2 count= 352
# --------------------
# /wiki/Talk:Main_Page/Archive_110 depth 2 count= 353
# --------------------
# /wiki/Talk:Main_Page/Archive_111 depth 2 count= 354
# --------------------
# /wiki/Talk:Main_Page/Archive_112 depth 2 count= 355
# --------------------
# /wiki/Talk:Main_Page/Archive_113 depth 2 count= 356
# --------------------
# /wiki/Talk:Main_Page/Archive_114 depth 2 count= 357
# --------------------
# /wiki/Talk:Main_Page/Archive_115 depth 2 count= 358
# --------------------
# /wiki/Talk:Main_Page/Archive_116 depth 2 count= 359
# --------------------
# /wiki/Talk:Main_Page/Archive_117 depth 2 count= 360
# --------------------
# /wiki/Talk:Main_Page/Archive_118 depth 2 count= 361
# --------------------
# /wiki/Talk:Main_Page/Archive_119 depth 2 count= 362
# --------------------
# /wiki/Talk:Main_Page/Archive_120 depth 2 count= 363
# --------------------
# /wiki/Talk:Main_Page/Archive_121 depth 2 count= 364
# --------------------
# /wiki/Talk:Main_Page/Archive_122 depth 2 count= 365
# --------------------
# /wiki/Talk:Main_Page/Archive_123 depth 2 count= 366
# --------------------
# /wiki/Talk:Main_Page/Archive_124 depth 2 count= 367
# --------------------
# /wiki/Talk:Main_Page/Archive_125 depth 2 count= 368
# --------------------
# /wiki/Talk:Main_Page/Archive_126 depth 2 count= 369
# --------------------
# /wiki/Talk:Main_Page/Archive_127 depth 2 count= 370
# --------------------
# /wiki/Talk:Main_Page/Archive_128 depth 2 count= 371
# --------------------
# /wiki/Talk:Main_Page/Archive_129 depth 2 count= 372
# --------------------
# /wiki/Talk:Main_Page/Archive_130 depth 2 count= 373
# --------------------
# /wiki/Talk:Main_Page/Archive_131 depth 2 count= 374
# --------------------
# /wiki/Talk:Main_Page/Archive_132 depth 2 count= 375
# --------------------
# /wiki/Talk:Main_Page/Archive_133 depth 2 count= 376
# --------------------
# /wiki/Talk:Main_Page/Archive_134 depth 2 count= 377
# --------------------
# /wiki/Talk:Main_Page/Archive_135 depth 2 count= 378
# --------------------
# /wiki/Talk:Main_Page/Archive_136 depth 2 count= 379
# --------------------
# /wiki/Talk:Main_Page/Archive_137 depth 2 count= 380
# --------------------
# /wiki/Talk:Main_Page/Archive_138 depth 2 count= 381
# --------------------
# /wiki/Talk:Main_Page/Archive_139 depth 2 count= 382
# --------------------
# /wiki/Talk:Main_Page/Archive_140 depth 2 count= 383
# --------------------
# /wiki/Talk:Main_Page/Archive_141 depth 2 count= 384
# --------------------
# /wiki/Talk:Main_Page/Archive_142 depth 2 count= 385
# --------------------
# /wiki/Talk:Main_Page/Archive_143 depth 2 count= 386
# --------------------
# /wiki/Talk:Main_Page/Archive_144 depth 2 count= 387
# --------------------
# /wiki/Talk:Main_Page/Archive_145 depth 2 count= 388
# --------------------
# /wiki/Talk:Main_Page/Archive_146 depth 2 count= 389
# --------------------
# /wiki/Talk:Main_Page/Archive_147 depth 2 count= 390
# --------------------
# /wiki/Talk:Main_Page/Archive_148 depth 2 count= 391
# --------------------
# /wiki/Talk:Main_Page/Archive_149 depth 2 count= 392
# --------------------
# /wiki/Talk:Main_Page/Archive_150 depth 2 count= 393
# --------------------
# /wiki/Talk:Main_Page/Archive_151 depth 2 count= 394
# --------------------
# /wiki/Talk:Main_Page/Archive_152 depth 2 count= 395
# --------------------
# /wiki/Talk:Main_Page/Archive_153 depth 2 count= 396
# --------------------
# /wiki/Talk:Main_Page/Archive_154 depth 2 count= 397
# --------------------
# /wiki/Talk:Main_Page/Archive_155 depth 2 count= 398
# --------------------
# /wiki/Talk:Main_Page/Archive_156 depth 2 count= 399
# --------------------
# /wiki/Talk:Main_Page/Archive_157 depth 2 count= 400
# --------------------
# /wiki/Talk:Main_Page/Archive_158 depth 2 count= 401
# --------------------
# /wiki/Talk:Main_Page/Archive_159 depth 2 count= 402
# --------------------
# /wiki/Talk:Main_Page/Archive_160 depth 2 count= 403
# --------------------
# /wiki/Talk:Main_Page/Archive_161 depth 2 count= 404
# --------------------
# /wiki/Talk:Main_Page/Archive_162 depth 2 count= 405
# --------------------
# /wiki/Talk:Main_Page/Archive_163 depth 2 count= 406
# --------------------
# /wiki/Talk:Main_Page/Archive_164 depth 2 count= 407
# --------------------
# /wiki/Talk:Main_Page/Archive_165 depth 2 count= 408
# --------------------
# /wiki/Talk:Main_Page/Archive_166 depth 2 count= 409
# --------------------
# /wiki/Talk:Main_Page/Archive_167 depth 2 count= 410
# --------------------
# /wiki/Talk:Main_Page/Archive_168 depth 2 count= 411
# --------------------
# /wiki/Talk:Main_Page/Archive_169 depth 2 count= 412
# --------------------
# /wiki/Talk:Main_Page/Archive_170 depth 2 count= 413
# --------------------
# /wiki/Talk:Main_Page/Archive_171 depth 2 count= 414
# --------------------
# /wiki/Talk:Main_Page/Archive_172 depth 2 count= 415
# --------------------
# /wiki/Talk:Main_Page/Archive_173 depth 2 count= 416
# --------------------
# /wiki/Talk:Main_Page/Archive_174 depth 2 count= 417
# --------------------
# /wiki/Talk:Main_Page/Archive_175 depth 2 count= 418
# --------------------
# /wiki/Talk:Main_Page/Archive_176 depth 2 count= 419
# --------------------
# /wiki/Talk:Main_Page/Archive_177 depth 2 count= 420
# --------------------
# /wiki/Talk:Main_Page/Archive_178 depth 2 count= 421
# --------------------
# /wiki/Talk:Main_Page/Archive_179 depth 2 count= 422
# --------------------
# /wiki/Talk:Main_Page/Archive_180 depth 2 count= 423
# --------------------
# /wiki/Talk:Main_Page/Archive_181 depth 2 count= 424
# --------------------
# /wiki/Talk:Main_Page/Archive_182 depth 2 count= 425
# --------------------
# /wiki/Talk:Main_Page/Archive_183 depth 2 count= 426
# --------------------
# /wiki/Talk:Main_Page/Archive_184 depth 2 count= 427
# --------------------
# /wiki/Talk:Main_Page/Archive_185 depth 2 count= 428
# --------------------
# /wiki/Talk:Main_Page/Archive_186 depth 2 count= 429
# --------------------
# /wiki/Talk:Main_Page/Archive_187 depth 2 count= 430
# --------------------
# /wiki/Talk:Main_Page/Archive_188 depth 2 count= 431
# --------------------
# /wiki/Talk:Main_Page/Archive_189 depth 2 count= 432
# --------------------
# /wiki/Talk:Main_Page/Archive_190 depth 2 count= 433
# --------------------
# /wiki/Talk:Main_Page/Archive_191 depth 2 count= 434
# --------------------
# /wiki/Talk:Main_Page/Archive_192 depth 2 count= 435
# --------------------
# /wiki/Talk:Main_Page/Archive_193 depth 2 count= 436
# --------------------
# /wiki/Talk:Main_Page/Archive_194 depth 2 count= 437
# --------------------
# /wiki/Talk:Main_Page/Archive_195 depth 2 count= 438
# --------------------
# /wiki/Talk:Main_Page/Archive_196 depth 2 count= 439
# --------------------
# /wiki/Talk:Main_Page/Archive_197 depth 2 count= 440
# --------------------
# /wiki/Talk:Main_Page/Archive_198 depth 2 count= 441
# --------------------
# /wiki/Talk:Main_Page/Archive_199 depth 2 count= 442
# --------------------
# /wiki/Talk:Main_Page/Archive_200 depth 2 count= 443
# --------------------
# /wiki/Talk:Main_Page/Archive_201 depth 2 count= 444
# --------------------
# /wiki/Talk:Main_Page/Archive_202 depth 2 count= 445
# --------------------
# /wiki/Talk:Main_Page/Archive_203 depth 2 count= 446
# --------------------
# /wiki/Talk:Main_Page/Archive_204 depth 2 count= 447
# --------------------
# /wiki/Talk:Main_Page/Archive_205 depth 2 count= 448
# --------------------
# /wiki/Talk:Main_Page/Archive_206 depth 2 count= 449
# --------------------
# /wiki/Wikipedia:Centralized_discussion depth 2 count= 450
# --------------------
# /wiki/Wikipedia:Village_pump_(policy) depth 2 count= 451
# --------------------
# /wiki/Wikipedia:Village_pump_(technical) depth 2 count= 452
# --------------------
# /wiki/Wikipedia:Village_pump_(proposals) depth 2 count= 453
# --------------------
# /wiki/Wikipedia:Village_pump_(idea_lab) depth 2 count= 454
# --------------------
# /wiki/Wikipedia:Village_pump_(WMF) depth 2 count= 455
# --------------------
# /wiki/Wikipedia:Village_pump_(miscellaneous) depth 2 count= 456
# --------------------
# /wiki/Wikipedia:Village_pump_(proposals)#RfC:_Enable_the_mergehistory_permission_for_importers depth 2 count= 457
# --------------------
# /wiki/Wikipedia_talk:Article_titles#Request_for_comment_on_the_relationship_between_WP:CRITERIA_and_WP:TITLEFORMAT depth 2 count= 458
# --------------------
# /wiki/Wikipedia:2024_open_letter_to_the_Wikimedia_Foundation depth 2 count= 459
# --------------------
# /wiki/Wikipedia:Village_pump_(proposals)#RfC:_Extended_confirmed_pending_changes_(PCECP) depth 2 count= 460
# --------------------
# /wiki/Wikipedia:Village_pump_(policy)#Date_redirects_to_portals? depth 2 count= 461
# --------------------
# /wiki/Wikipedia_talk:Administrator_recall#RfC:_Should_we_add_text_prescribing_just_signatures,_no_discussion? depth 2 count= 462
# --------------------
# /wiki/Wikipedia:Requests_for_comment/Shorten_recall_petition_period depth 2 count= 463
# --------------------
# /wiki/Template:Centralized_discussion depth 2 count= 464
# --------------------
# /wiki/Wikipedia:Centralized_discussion/Archive depth 2 count= 465
# --------------------
# /wiki/Wikipedia_talk:Centralized_discussion depth 2 count= 466
# --------------------
# /wiki/Wikipedia:Manual_of_Style#Opportunities_for_commonality depth 2 count= 467
# --------------------
# /wiki/Wikipedia:Manual_of_Style#National_varieties_of_English depth 2 count= 468
# --------------------
# /wiki/Comparison_of_American_and_British_English depth 2 count= 469
# --------------------
# /wiki/Wikipedia:Today%27s_featured_article/November_19,_2024 depth 2 count= 470
# --------------------
# /wiki/Wikipedia:Today%27s_featured_article/November_20,_2024 depth 2 count= 471
# --------------------
# /wiki/Wikipedia:Today%27s_featured_article/November_21,_2024 depth 2 count= 472
# --------------------
# /wiki/Wikipedia:Selected_anniversaries/November_19 depth 2 count= 473
# --------------------
# /wiki/Wikipedia:Selected_anniversaries/November_20 depth 2 count= 474
# --------------------
# /wiki/Wikipedia:Selected_anniversaries/November_21 depth 2 count= 475
# --------------------
# /wiki/Template:POTD_protected/2024-11-19 depth 2 count= 476
# --------------------
# /wiki/Template:POTD_protected/2024-11-20 depth 2 count= 477
# --------------------
# /wiki/Template:POTD_protected/2024-11-21 depth 2 count= 478
# --------------------
# /wiki/Template:POTD/2024-11-19 depth 2 count= 479
# --------------------
# /wiki/Template:POTD/2024-11-20 depth 2 count= 480
# --------------------
# /wiki/Template:POTD/2024-11-21 depth 2 count= 481
# --------------------
# /wiki/User:DYKUpdateBot/Errors depth 2 count= 482
# --------------------
# /wiki/Wikipedia:Main_Page/Commons_media_protection depth 2 count= 483
# --------------------
# /wiki/Category:Protected_pages_associated_with_Main_Page_articles depth 2 count= 484
# --------------------
# /wiki/Wikipedia:Main_Page/styles.css depth 2 count= 485
# --------------------
# /wiki/Wikipedia:Main_Page/sandbox/styles.css depth 2 count= 486
# --------------------
# /wiki/Coordinated_Universal_Time depth 2 count= 487
# --------------------
# /wiki/Special:Purge/Main_Page depth 2 count= 488
# --------------------
# /wiki/Special:Purge/Talk:Main_Page depth 2 count= 489
# --------------------
# /wiki/Wikipedia:Be_bold depth 2 count= 490
# --------------------
# /wiki/Template:Edit_fully-protected depth 2 count= 491
# --------------------
# /wiki/Special:PermanentLink/587856532#Any_other_problems depth 2 count= 492
# --------------------
# /wiki/Wikipedia:Civility depth 2 count= 493
# --------------------
# /wiki/Help:Archiving_a_talk_page depth 2 count= 494
# --------------------
# /wiki/Wikipedia_talk:ERRORS depth 2 count= 495
# --------------------
# /wiki/Wikipedia:SUBSCRIBE depth 2 count= 496
# --------------------
# /wiki/User_talk:Dank depth 2 count= 497
# --------------------
# /wiki/Wikipedia:Today%27s_featured_article/November_22,_2024 depth 2 count= 498
# --------------------
# /wiki/Helmut_Bauer_(bishop) depth 2 count= 499
# --------------------
# /wiki/Roman_Catholic_Diocese_of_W%C3%BCrzburg depth 2 count= 500
# --------------------
# /wiki/Gotteslob depth 2 count= 501
# --------------------
# /wiki/Confirmation_in_the_Catholic_Church depth 2 count= 502
# --------------------
# /wiki/User:Gerda_Arendt depth 2 count= 503
# --------------------
# /wiki/User_talk:Gerda_Arendt depth 2 count= 504
# --------------------
# /wiki/User:Launchballer depth 2 count= 505
# --------------------
# /wiki/User:Crisco_1492 depth 2 count= 506
# --------------------
# /wiki/User_talk:Crisco_1492 depth 2 count= 507
# --------------------
# /wiki/User:Ravenpuff depth 2 count= 508
# --------------------
# /wiki/User_talk:Launchballer depth 2 count= 509
# --------------------
# /wiki/Special:Contributions/Launchballer depth 2 count= 510
# --------------------
# /wiki/User:AirshipJungleman29 depth 2 count= 511
# --------------------
# /wiki/User_talk:AirshipJungleman29 depth 2 count= 512
# --------------------
# /wiki/Template:Did_you_know/Queue/2 depth 2 count= 513
# --------------------
# /wiki/Template:Did_you_know/Queue/3 depth 2 count= 514
# --------------------
# /wiki/Wikipedia:Selected_anniversaries/November_22 depth 2 count= 515
# --------------------
# /wiki/Wikipedia:Today%27s_featured_list/November_22,_2024 depth 2 count= 516
# --------------------
# /wiki/Wikipedia:Today%27s_featured_list/November_25,_2024 depth 2 count= 517
# --------------------
# /wiki/Category:Main_Page_discussions depth 2 count= 518
# --------------------
# /wiki/Category:Articles_with_short_description depth 2 count= 519
# --------------------
# /wiki/Category:Wikipedia_semi-protected_talk_pages depth 2 count= 520
# --------------------
# /wiki/Special:WhatLinksHere/Main_Page depth 1 count= 521
# --------------------
# header= Pages that link to "Main Page"
# first paragraph=  <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/Main_Page" title="Main Page">Main Page</a></b> <span id="specialDeleteLink"></span>
# </p>
# attribute error: 'NoneType' object has no attribute 'find'
# /wiki/Help:What_links_here depth 2 count= 522
# --------------------
# /wiki/Help:What_links_here#Transclusion depth 2 count= 523
# --------------------
# /wiki/Home_page depth 2 count= 524
# --------------------
# /wiki/Internet_Explorer depth 2 count= 525
# --------------------
# /wiki/Man_page depth 2 count= 526
# --------------------
# /wiki/Smartphone depth 2 count= 527
# --------------------
# /wiki/Talk:Swabian_Jura depth 2 count= 528
# --------------------
# /wiki/Talk:Western_Brook_Pond depth 2 count= 529
# --------------------
# /wiki/Talk:Danish_Realm/Archive_1 depth 2 count= 530
# --------------------
# /wiki/Talk:2021_Indian_Air_Force_Mil_Mi-17_crash depth 2 count= 531
# --------------------
# /wiki/Talk:Kozar%C4%8Danka/Archive_1 depth 2 count= 532
# --------------------
# /wiki/User:ARIYA,Ginzang depth 2 count= 533
# --------------------
# /wiki/User:BOTijo depth 2 count= 534
# --------------------
# /wiki/User:Stasaahk depth 2 count= 535
# --------------------
# /wiki/User:Henning_M depth 2 count= 536
# --------------------
# /wiki/User:BOTijo/info depth 2 count= 537
# --------------------
# /wiki/User:AvatarTeam depth 2 count= 538
# --------------------
# /wiki/User:Emijrp/BOTijoInfo.css depth 2 count= 539
# --------------------
# /wiki/User:Tim.landscheidt/Sandbox/Transclusions_of_deleted_templates/2 depth 2 count= 540
# --------------------
# /wiki/User:Acer/Simple2 depth 2 count= 541
# --------------------
# /wiki/User:RileyBugz/Navigation depth 2 count= 542
# --------------------
# /wiki/User:Waterlemon147/sandbox depth 2 count= 543
# --------------------
# /wiki/User:IgnatiusofLondon depth 2 count= 544
# --------------------
# /wiki/User_talk:Obama19 depth 2 count= 545
# --------------------
# /wiki/User_talk:Cronholm144 depth 2 count= 546
# --------------------
# /wiki/User_talk:Hydrogen_Iodide/Archive_5 depth 2 count= 547
# --------------------
# /wiki/User_talk:Kafka_Liz/Archive_5 depth 2 count= 548
# --------------------
# /wiki/User_talk:3dprinterkart depth 2 count= 549
# --------------------
# /wiki/User_talk:4SurrealArtist depth 2 count= 550
# --------------------
# /wiki/User_talk:The-Pope/Archive_11 depth 2 count= 551
# --------------------
# /wiki/User_talk:Amjadum depth 2 count= 552
# --------------------
# /wiki/User_talk:Deepakgu14 depth 2 count= 553
# --------------------
# /wiki/User_talk:Al_Zain_Poulry_Farms depth 2 count= 554
# --------------------
# /wiki/Wikipedia:Help_desk/Archives/2007_April_15 depth 2 count= 555
# --------------------
# /wiki/Wikipedia:Help_desk/Archives/2009_February_13 depth 2 count= 556
# --------------------
# /wiki/Wikipedia:Wikipedia_Signpost/2020-03-01/Discussion_report depth 2 count= 557
# --------------------
# /wiki/Wikipedia:Wikipedia_Signpost/Single/2020-03-01 depth 2 count= 558
# --------------------
# /wiki/Wikipedia:Requests_for_page_protection/Archive/2019/01 depth 2 count= 559
# --------------------
# /wiki/Wikipedia:Wikipedia_Signpost/2024-01-10/In_focus depth 2 count= 560
# --------------------
# /wiki/Wikipedia:Wikipedia_Signpost/Single/2024-01-10 depth 2 count= 561
# --------------------
# /wiki/Wikipedia:Help_desk/Archives/2024_April_14 depth 2 count= 562
# --------------------
# /wiki/MediaWiki_talk:Vector.css depth 2 count= 563
# --------------------
# /wiki/Template:Is_redirect/doc depth 2 count= 564
# --------------------
# /wiki/Template:Is_redirect depth 2 count= 565
# --------------------
# /wiki/Template:Is_redirect/sandbox depth 2 count= 566
# --------------------
# /wiki/Talk:CS_gas depth 2 count= 567
# --------------------
# ...
# --------------------
# header= The Posthumous Memoirs of Brás Cubas
# first paragraph=  <p><i><b>The Posthumous Memoirs of Brás Cubas</b></i> (<a href="/wiki/Portuguese_language" title="Portuguese language">Portuguese</a>: <i lang="pt">Memorias Posthumas de Braz Cubas</i>, modern spelling <i>Memórias Póstumas de Brás Cubas</i>), also translated as <i><b>Epitaph of a Small Winner</b></i>, is a novel by the <a class="mw-redirect" href="/wiki/Brazilian_people" title="Brazilian people">Brazilian</a> writer <a class="mw-redirect" href="/wiki/Joaquim_Maria_Machado_de_Assis" title="Joaquim Maria Machado de Assis">Joaquim Maria Machado de Assis</a> that is regarded as one of the greatest works of Brazilian literature. The book is presented as the memoirs of its protagonist, Brás Cubas, as told from beyond the grave.
# </p>
# attribute error: 'NoneType' object has no attribute 'attrs'
# /wiki/Talk:The_Posthumous_Memoirs_of_Br%C3%A1s_Cubas depth 2 count= 21669
# --------------------
# /wiki/Special:WhatLinksHere/The_Posthumous_Memoirs_of_Br%C3%A1s_Cubas depth 2 count= 21670
# --------------------
# /wiki/Special:RecentChangesLinked/The_Posthumous_Memoirs_of_Br%C3%A1s_Cubas depth 2 count= 21671
# --------------------
# /wiki/Wikipedia:Citing_sources#General_references depth 2 count= 21672
# --------------------
# /wiki/Wikipedia:WikiProject_Reliability depth 2 count= 21673
# --------------------
# /wiki/Wikipedia:When_to_cite depth 2 count= 21674
# --------------------
# /wiki/File:Memorias_Posthumas_de_Braz_Cubas.jpg depth 2 count= 21675
# --------------------
# /wiki/Funda%C3%A7%C3%A3o_Biblioteca_Nacional depth 2 count= 21676
# --------------------
# /wiki/Joaquim_Maria_Machado_de_Assis depth 2 count= 21677
# --------------------
# /wiki/Gregory_Rabassa depth 2 count= 21678
# --------------------
# /wiki/Novel depth 2 count= 21679
# --------------------
# /wiki/Hardcover depth 2 count= 21680
# --------------------
# /wiki/Paperback depth 2 count= 21681
# --------------------
# /wiki/Special:BookSources/0-19-510169-3 depth 2 count= 21682
# --------------------
# /wiki/Dewey_Decimal_Classification depth 2 count= 21683
# --------------------
# /wiki/LCC_(identifier) depth 2 count= 21684
# --------------------
# /wiki/Brazilian_people depth 2 count= 21685
# --------------------
# /wiki/Metaphor depth 2 count= 21686
# --------------------
# /wiki/Post-modernism depth 2 count= 21687
# --------------------
# /wiki/John_Barth depth 2 count= 21688
# --------------------
# /wiki/Donald_Barthelme depth 2 count= 21689
# --------------------
# /wiki/Poultice depth 2 count= 21690
# --------------------
# /wiki/Coimbra depth 2 count= 21691
# --------------------
# /wiki/Gamboa,_Rio_de_Janeiro depth 2 count= 21692
# --------------------
# /wiki/Arthur_Schopenhauer depth 2 count= 21693
# --------------------
# /wiki/German_people depth 2 count= 21694
# --------------------
# /wiki/Masterpiece depth 2 count= 21695
# --------------------
# /wiki/The_World_as_Will_and_Representation depth 2 count= 21696
# --------------------
# /wiki/Myrmecia_(ant) depth 2 count= 21697
# --------------------
# /wiki/Positivism depth 2 count= 21698
# --------------------
# /wiki/Woody_Allen depth 2 count= 21699
# --------------------
# /wiki/Parul_Sehgal depth 2 count= 21700
# --------------------
# /wiki/Dave_Eggers depth 2 count= 21701
# --------------------
# /wiki/Margaret_Jull_Costa depth 2 count= 21702
# --------------------
# /wiki/Special:BookSources/978-0-19-510169-0 depth 2 count= 21703
# --------------------
# /wiki/Wikisource depth 2 count= 21704
# --------------------
# /wiki/LibriVox depth 2 count= 21705
# --------------------
# /wiki/Template:Works_by_Machado_de_Assis depth 2 count= 21706
# --------------------
# /wiki/Template_talk:Works_by_Machado_de_Assis depth 2 count= 21707
# --------------------
# /wiki/Special:EditPage/Template:Works_by_Machado_de_Assis depth 2 count= 21708
# --------------------
# /wiki/Category:Works_by_Machado_de_Assis depth 2 count= 21709
# --------------------
# /wiki/Category:Novels_by_Machado_de_Assis depth 2 count= 21710
# --------------------
# /wiki/Helena_(Machado_de_Assis_novel) depth 2 count= 21711
# --------------------
# /wiki/Esau_and_Jacob_(novel) depth 2 count= 21712
# --------------------
# /wiki/O_alienista depth 2 count= 21713
# --------------------
# /wiki/The_Case_of_the_Stick depth 2 count= 21714
# --------------------
# /wiki/The_Alienist_(film) depth 2 count= 21715
# --------------------
# /wiki/Mem%C3%B3rias_P%C3%B3stumas depth 2 count= 21716
# --------------------
# /wiki/Capitu depth 2 count= 21717
# --------------------
# /wiki/Category:1881_Brazilian_novels depth 2 count= 21718
# --------------------
# /wiki/Category:Portuguese-language_novels depth 2 count= 21719
# --------------------
# /wiki/Category:Articles_lacking_in-text_citations_from_May_2011 depth 2 count= 21720
# --------------------
# /wiki/Category:All_articles_lacking_in-text_citations depth 2 count= 21721
# --------------------
# /wiki/Category:Articles_containing_Portuguese-language_text depth 2 count= 21722
# --------------------
# /wiki/Category:Articles_with_LibriVox_links depth 2 count= 21723
# --------------------
# /wiki/Marc_Ferrez_(photographer) depth 1 count= 21724
# --------------------
# header= Marc Ferrez (photographer)
# first paragraph=  <p class="mw-empty-elt">
# </p>
# attribute error: 'NoneType' object has no attribute 'attrs'
# /wiki/Talk:Marc_Ferrez_(photographer) depth 2 count= 21725
# --------------------
# /wiki/Special:WhatLinksHere/Marc_Ferrez_(photographer) depth 2 count= 21726
# --------------------
# /wiki/Special:RecentChangesLinked/Marc_Ferrez_(photographer) depth 2 count= 21727
# --------------------
# /wiki/File:Marc_Ferrez_(3x4_cropped).jpg depth 2 count= 21728
# --------------------
# /wiki/Zepherin_Ferrez depth 2 count= 21729
# --------------------
# /wiki/File:Marc_Ferrez_signature.jpg depth 2 count= 21730
# --------------------
# /wiki/File:Porto_de_Santos,_1870.jpg depth 2 count= 21731
# --------------------
# /wiki/Port_of_Santos depth 2 count= 21732
# --------------------
# /wiki/William_Henry_Jackson depth 2 count= 21733
# --------------------
# /wiki/Eadweard_Muybridge depth 2 count= 21734
# --------------------
# /wiki/Pedro_II_of_Brazil depth 2 count= 21735
# --------------------
# /wiki/Panoramic_photography depth 2 count= 21736
# --------------------
# /wiki/Plantation depth 2 count= 21737
# --------------------
# /wiki/Charles_Frederick_Hartt depth 2 count= 21738
# --------------------
# /wiki/Botocudo depth 2 count= 21739
# --------------------
# /wiki/Wikipedia:Manual_of_Style/Words_to_watch#Unsupported_attributions depth 2 count= 21740
# --------------------
# /wiki/Metropolis depth 2 count= 21741
# --------------------
# /wiki/Ethnology depth 2 count= 21742
# --------------------
# /wiki/Centennial_International_Exhibition depth 2 count= 21743
# --------------------
# /wiki/South_American_Continental_Exhibition depth 2 count= 21744
# --------------------
# /wiki/Buenos_Aires depth 2 count= 21745
# --------------------
# /wiki/St._Louis_Worlds_Fair depth 2 count= 21746
# --------------------
# /wiki/File:Marc_Ferrez_-_IMS_007A6P4FP15-015.jpg depth 2 count= 21747
# --------------------
# /wiki/Corcovado depth 2 count= 21748
# --------------------
# /wiki/Special:BookSources/978-0-684-19253-6 depth 2 count= 21749
# --------------------
# /wiki/Category:1843_births depth 2 count= 21750
# --------------------
# /wiki/Category:1923_deaths depth 2 count= 21751
# --------------------
# /wiki/Category:Brazilian_photographers depth 2 count= 21752
# --------------------
# /wiki/Category:Brazilian_people_of_French_descent depth 2 count= 21753
# --------------------
# /wiki/Category:People_from_Rio_de_Janeiro_(city) depth 2 count= 21754
# --------------------
# /wiki/Category:Use_dmy_dates_from_November_2022 depth 2 count= 21755
# --------------------
# /wiki/Category:Biography_with_signature depth 2 count= 21756
# --------------------
# /wiki/Category:Articles_with_specifically_marked_weasel-worded_phrases_from_February_2024 depth 2 count= 21757
# --------------------
# /wiki/Template:POTD/2024-11-18 depth 1 count= 21758
# --------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 crawler()
#
# Cell In[1], line 50, in crawler()
#      47         print(f"Excpetion occured: {e}")
#      48         return
# ---> 50 getLinks('',0)
#
# Cell In[1], line 45, in crawler.<locals>.getLinks(pageUrl, depth)
#      40             pages.add(newPage)
#      42             # print(pages)
#      43             # add to visited
#      44             # go and crawl this link
# ---> 45             getLinks(newPage,depth+1)
#      46 except Exception as e:
#      47     print(f"Excpetion occured: {e}")
#
# Cell In[1], line 45, in crawler.<locals>.getLinks(pageUrl, depth)
#      40             pages.add(newPage)
#      42             # print(pages)
#      43             # add to visited
#      44             # go and crawl this link
# ---> 45             getLinks(newPage,depth+1)
#      46 except Exception as e:
#      47     print(f"Excpetion occured: {e}")
#
# Cell In[1], line 17, in crawler.<locals>.getLinks(pageUrl, depth)
#      14 # open html
#      15 try:
# ---> 17     html=urlopen("http://en.wikipedia.org{}".format(pageUrl))
#      18     # create a beautiful soup object
#      19     bs=BeautifulSoup(html.read(),"html.parser")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:553, in OpenerDirector.error(self, proto, *args)
#     551     http_err = 0
#     552 args = (dict, proto, meth_name) + args
# --> 553 result = self._call_chain(*args)
#     554 if result:
#     555     return result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:745, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     742 fp.read()
#     743 fp.close()
# --> 745 return self.parent.open(new, timeout=req.timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
#     517 # post-process response
#     518 meth_name = protocol+"_response"
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:532, in OpenerDirector._open(self, req, data)
#     529     return result
#     531 protocol = req.type
# --> 532 result = self._call_chain(self.handle_open, protocol, protocol +
#     533                           '_open', req)
#     534 if result:
#     535     return result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:1392, in HTTPSHandler.https_open(self, req)
#    1391 def https_open(self, req):
# -> 1392     return self.do_open(http.client.HTTPSConnection, req,
#    1393                         context=self._context)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1342 try:
#    1343     try:
# -> 1344         h.request(req.get_method(), req.selector, req.data, headers,
#    1345                   encode_chunked=req.has_header('Transfer-encoding'))
#    1346     except OSError as err: # timeout error
#    1347         raise URLError(err)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1319, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1316 def request(self, method, url, body=None, headers={}, *,
#    1317             encode_chunked=False):
#    1318     """Send a complete request to the server."""
# -> 1319     self._send_request(method, url, body, headers, encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1365, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1361 if isinstance(body, str):
#    1362     # RFC 2616 Section 3.7.1 says that text default has a
#    1363     # default charset of iso-8859-1.
#    1364     body = _encode(body, 'body')
# -> 1365 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1314, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1312 else:
#    1313     raise CannotSendHeader()
# -> 1314 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1074, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1072 msg = b"\r\n".join(self._buffer)
#    1073 del self._buffer[:]
# -> 1074 self.send(msg)
#    1076 if message_body is not None:
#    1077
#    1078     # create a consistent interface to message_body
#    1079     if hasattr(message_body, 'read'):
#    1080         # Let file-like take precedence over byte-like.  This
#    1081         # is needed to allow the current position of mmap'ed
#    1082         # files to be taken into account.
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1018, in HTTPConnection.send(self, data)
#    1016 if self.sock is None:
#    1017     if self.auto_open:
# -> 1018         self.connect()
#    1019     else:
#    1020         raise NotConnected()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1453, in HTTPSConnection.connect(self)
#    1450 def connect(self):
#    1451     "Connect to a host on a given (SSL) port."
# -> 1453     super().connect()
#    1455     if self._tunnel_host:
#    1456         server_hostname = self._tunnel_host
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:984, in HTTPConnection.connect(self)
#     982 """Connect to the host and port specified in __init__."""
#     983 sys.audit("http.client.connect", self, self.host, self.port)
# --> 984 self.sock = self._create_connection(
#     985     (self.host,self.port), self.timeout, self.source_address)
#     986 # Might fail in OSs that don't implement TCP_NODELAY
#     987 try:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:837, in create_connection(address, timeout, source_address, all_errors)
#     835 if source_address:
#     836     sock.bind(source_address)
# --> 837 sock.connect(sa)
#     838 # Break explicitly a reference cycle
#     839 exceptions.clear()
#
# KeyboardInterrupt:
